# %% [markdown]
# <center>
#
# # ФБ-24 Шевченко Вікторія
# ## Лабораторна робота №4
# ## Структури для роботи з великими обсягами даних в Python
# ## Перший рівень
#
# </center>

# %%
import pandas as pd
import os
import datetime
import numpy as np
from IPython.display import display
import time

# %%
def txt_to_csv(txt_file, csv_file, delimiter=';'):

    if os.path.exists(csv_file):
        os.remove(csv_file)  

    df = pd.read_csv(txt_file, delimiter=delimiter)
    df.to_csv(csv_file, index=False)
    df.info()
txt_file_path = 'household_power_consumption.txt'
csv_file_path = 'household_power_consumption.csv'

txt_to_csv(txt_file_path, csv_file_path)
# Out:
# C:\Users\kvdre\AppData\Local\Temp\ipykernel_20572\3145550955.py:6: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(txt_file, delimiter=delimiter)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %% [markdown]
# <h3>Зчитування файла за допомогою pandas</h3>

# %%
def pd_df(csv_file_path):
    dtype = {
        'Global_active_power': float,
        'Global_reactive_power': float,
        'Voltage': float,
        'Global_intensity': float,
        'Sub_metering_1': float,
        'Sub_metering_2': float,
        'Sub_metering_3': float
    }

    df = pd.read_csv(csv_file_path, dtype=dtype, na_values='?')
    df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
    df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.time
    df.dropna(inplace=True)
    return df
csv_file_path = 'household_power_consumption.csv'
df = pd_df(csv_file_path)    
display(df.head())
print(df.isnull().sum())
# Out:
#         Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00                4.216                  0.418   234.84
# 1 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2 2006-12-16  17:26:00                5.374                  0.498   233.29
# 3 2006-12-16  17:27:00                5.388                  0.502   233.74
# 4 2006-12-16  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0
# Date                     0
# Time                     0
# Global_active_power      0
# ...

# %% [markdown]
# <h3>Зчитування файла за допомогою numpy</h3>

# %%
data = np.genfromtxt('household_power_consumption.csv', delimiter=',', dtype=str, skip_header=1)
#data[(data == '?') | (data == '')] = '0'

# %%
#numeric_data = data[:, 2:].astype(float)
#npdata = np.column_stack((data[:, :2], numeric_data))
#data[:, 2:].astype(float)
#print(data)
#data.shape
#print(numeric_data)


npdata = df.values
npdata[:, 0] = np.array([str(x) for x in npdata[:, 0]])
npdata[:, 1] = np.array([str(x) for x in npdata[:, 1]])
print(npdata)
# Out:
# [['2006-12-16 00:00:00' '17:24:00' 4.216 ... 0.0 1.0 17.0]
#  ['2006-12-16 00:00:00' '17:25:00' 5.36 ... 0.0 1.0 16.0]
#  ['2006-12-16 00:00:00' '17:26:00' 5.374 ... 0.0 2.0 17.0]
#  ...
#  ['2010-11-26 00:00:00' '21:00:00' 0.938 ... 0.0 0.0 0.0]
#  ['2010-11-26 00:00:00' '21:01:00' 0.934 ... 0.0 0.0 0.0]
#  ['2010-11-26 00:00:00' '21:02:00' 0.932 ... 0.0 0.0 0.0]]

# %% [markdown]
# <h3>Перелік атрибутивної інформації:</h3>
# <h5>
# <ul>
# <li>date: дата виміру у форматі dd/mm/yyyy</li>
# <li>time: час у форматі hh:mm:ss</li>
# <li>global_active_power: активна потужність, яку споживає домогосподарство за хвилину (усереднено) [кВт]</li>
# <li>global_reactive_power: реактивна потужність, яку споживає домогосподарство за хвилину (усереднено) [кВт]</li>
# <li>voltage: напруга, усереднена за хвилину спостереження [В]</li>
# <li>global_intensity: усереднена силу струму для домогосподарства [A]</li>
# <li>sub_metering_1: набір споживачів енергії No1 [Вт-годин активної енергії], відповідає кухні, на якій є машина для миття посуду на мікрохвильовка (електричної плити немає, використовується газова).</li>
# <li>sub_metering_2: набір споживачів енергії No2 [Вт-годин активної енергії], відповідає пральні, в якій працює пральна машина, сушарка, холодильних та ввімкнено світло.</li>
# <li>sub_metering_3: набір споживачів енергії No3 [Вт-годин][Вт-годин активної енергії], відповідає бойлеру та кондиціонеру.</li>
# </ul>
# </h5>

# %% [markdown]
# <h3> 1. Обрати всі домогосподарства, у яких загальна активна споживана потужність перевищує 5 кВт</h3>

# %%
def power_over_5(df):
    result_df = df[df['Global_active_power'] > 5.0]
    
    return result_df

start_time = time.time()
filtered_df = power_over_5(df)
result_dataframe = power_over_5(df)
display(result_dataframe)
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 1       2006-12-16  17:25:00                5.360                  0.436
# 2       2006-12-16  17:26:00                5.374                  0.498
# 3       2006-12-16  17:27:00                5.388                  0.502
# 11      2006-12-16  17:35:00                5.412                  0.470
# 12      2006-12-16  17:36:00                5.224                  0.478
# ...            ...       ...                  ...                    ...
# 2069356 2010-11-22  18:40:00                5.408                  0.150
# 2069357 2010-11-22  18:41:00                5.528                  0.144
# 2071586 2010-11-24  07:50:00                5.172                  0.050
# 2071587 2010-11-24  07:51:00                5.750                  0.000
# 2072997 2010-11-25  07:21:00                5.074                  0.240
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# <h3>NumPy:</h3>

# %%
def power_over_5_np(nparray):
    filtered_np = nparray[nparray[:, 2] > 5]
    
    return filtered_np


start_time = time.time()
result_np = power_over_5_np(npdata)
print(result_np)
end_time = time.time() - start_time
print(f"Час виконання Numpy: {end_time}")
# Out:
# [['2006-12-16 00:00:00' '17:25:00' 5.36 ... 0.0 1.0 16.0]
#  ['2006-12-16 00:00:00' '17:26:00' 5.374 ... 0.0 2.0 17.0]
#  ['2006-12-16 00:00:00' '17:27:00' 5.388 ... 0.0 1.0 17.0]
#  ...
#  ['2010-11-24 00:00:00' '07:50:00' 5.172 ... 0.0 38.0 17.0]
#  ['2010-11-24 00:00:00' '07:51:00' 5.75 ... 0.0 39.0 17.0]
#  ['2010-11-25 00:00:00' '07:21:00' 5.074 ... 1.0 2.0 18.0]]
# Час виконання Numpy: 0.06980633735656738

# %% [markdown]
# <h3> 2. Обрати всі домогосподарства, у яких вольтаж перевищую 235 В.</h3>

# %%
def voltage_over_235(df):

    result_df = df[df['Voltage'] > 235]
    
    return result_df

start_time = time.time()
result_dataframe = voltage_over_235(df)
display(result_dataframe)
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 4       2006-12-16  17:28:00                3.666                  0.528
# 5       2006-12-16  17:29:00                3.520                  0.522
# 6       2006-12-16  17:30:00                3.702                  0.520
# 7       2006-12-16  17:31:00                3.700                  0.520
# 14      2006-12-16  17:38:00                4.054                  0.422
# ...            ...       ...                  ...                    ...
# 2075254 2010-11-26  20:58:00                0.946                  0.000
# 2075255 2010-11-26  20:59:00                0.944                  0.000
# 2075256 2010-11-26  21:00:00                0.938                  0.000
# 2075257 2010-11-26  21:01:00                0.934                  0.000
# 2075258 2010-11-26  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# <h3>NumPy:</h3>

# %%
def voltage_over_235_np(nparray):

    result_np = nparray[nparray[:, 4] > 235]
    
    return result_np

start_time = time.time()
result_npdataframe = voltage_over_235_np(npdata)
print(result_npdataframe)
end_time = time.time() - start_time
print(f"Час виконання Numpy: {end_time}")
# Out:
# [['2006-12-16 00:00:00' '17:28:00' 3.666 ... 0.0 1.0 17.0]
#  ['2006-12-16 00:00:00' '17:29:00' 3.52 ... 0.0 2.0 17.0]
#  ['2006-12-16 00:00:00' '17:30:00' 3.702 ... 0.0 1.0 17.0]
#  ...
#  ['2010-11-26 00:00:00' '21:00:00' 0.938 ... 0.0 0.0 0.0]
#  ['2010-11-26 00:00:00' '21:01:00' 0.934 ... 0.0 0.0 0.0]
#  ['2010-11-26 00:00:00' '21:02:00' 0.932 ... 0.0 0.0 0.0]]
# Час виконання Numpy: 0.4322662353515625

# %% [markdown]
# <h3> 3. Обрати всі домогосподарства, у яких сила струму лежить в межах 19-20 А, для них виявити ті, у яких пральна машина та холодильних споживають більше, ніж бойлер та кондиціонер.</h3>

# %%
def within_current_range(df):
    filtered_df = df[(df['Global_intensity'] >= 19) & (df['Global_intensity'] <= 20)]
    
    result_df = filtered_df[(filtered_df['Sub_metering_2'] > filtered_df['Sub_metering_3'])]
    
    return result_df

start_time = time.time()
result_dataframe = within_current_range(df)
display(result_dataframe)
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 45      2006-12-16  18:09:00                4.464                  0.136
# 460     2006-12-17  01:04:00                4.582                  0.258
# 464     2006-12-17  01:08:00                4.618                  0.104
# 475     2006-12-17  01:19:00                4.636                  0.140
# 476     2006-12-17  01:20:00                4.634                  0.152
# ...            ...       ...                  ...                    ...
# 2071589 2010-11-24  07:53:00                4.666                  0.000
# 2071590 2010-11-24  07:54:00                4.694                  0.000
# 2071591 2010-11-24  07:55:00                4.602                  0.000
# 2071592 2010-11-24  07:56:00                4.536                  0.000
# 2071593 2010-11-24  07:57:00                4.626                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# <h3>NumPy:</h3>

# %%
def within_current_range_np(nparray):
    filtered_np = nparray[(nparray[:, 3] >= 19) & (nparray[:, 3] <= 20)]
    result_np = filtered_np[(filtered_np[:, 7] > filtered_np[:, 8])]
    
    return result_np

start_time = time.time()
result_npdataframe = within_current_range_np(npdata)
display(result_dataframe)
end_time = time.time() - start_time
print(f"Час виконання Numpy: {end_time}")
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 45      2006-12-16  18:09:00                4.464                  0.136
# 460     2006-12-17  01:04:00                4.582                  0.258
# 464     2006-12-17  01:08:00                4.618                  0.104
# 475     2006-12-17  01:19:00                4.636                  0.140
# 476     2006-12-17  01:20:00                4.634                  0.152
# ...            ...       ...                  ...                    ...
# 2071589 2010-11-24  07:53:00                4.666                  0.000
# 2071590 2010-11-24  07:54:00                4.694                  0.000
# 2071591 2010-11-24  07:55:00                4.602                  0.000
# 2071592 2010-11-24  07:56:00                4.536                  0.000
# 2071593 2010-11-24  07:57:00                4.626                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# <h3>4. Обрати випадковим чином 500000 домогосподарств (без повторів елементів вибірки), для них обчислити середні величини усіх 3-х груп споживання електричної енергії</h3>

# %%
def random_house_avarage(df, x=500000):
    random_indices = df.sample(n=x, replace=False).index
    random_raw = df.loc[random_indices]
    average_value = random_raw[['Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']].mean()
    
    return average_value

start_time = time.time()
average_value = random_house_avarage(df)
print(average_value)
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
# Sub_metering_1    1.124336
# Sub_metering_2    1.298944
# Sub_metering_3    6.446376
# dtype: float64
# Час виконання Pd: 0.5291283130645752

# %% [markdown]
# <h3>NumPy:</h3>

# %%
def random_house_avarage_np(nparray, x=500000):
    random_indices = np.random.choice(np.arange(nparray.shape[0]), size=x, replace=False)
    random_raw = nparray[random_indices]
    average_value = np.mean(random_raw[:, 6:9], axis=0)
    
    return average_value

start_time = time.time()
average_value = random_house_avarage_np(npdata)
print(average_value)
end_time = time.time() - start_time
print(f"Час виконання Numpy: {end_time}")
# Out:
# [1.11586 1.297136 6.461902]
# Час виконання Numpy: 0.6865839958190918

# %% [markdown]
# <h3> 5. Обрати ті домогосподарства, які після 18-00 споживають понад 6 кВт за хвилину в середньому, серед відібраних визначити ті, у яких основне споживання електроенергії у вказаний проміжок часу припадає на пральну машину, сушарку, холодильник та освітлення (група 2 є найбільшою), а потім обрати кожен третій результат із першої половини та кожен четвертий результат із другої половини.</h3>

# %%
def select_households(df):
    filtered_df = df[(df['Time'] > datetime.time(18, 0, 0)) & (df['Global_active_power'] > 6.0)]

    final_df = filtered_df[(filtered_df['Sub_metering_2'] > filtered_df['Sub_metering_1']) &
                              (filtered_df['Sub_metering_2'] > filtered_df['Sub_metering_3'])]
   
    first_half = final_df.head(len(final_df) // 2)
    second_half = final_df.tail(len(final_df) // 2)
    result_df = pd.concat([first_half.iloc[::3, :], second_half.iloc[::4, :]])
    return result_df

start_time = time.time()
result = select_households(df)
display(result.head())
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
#             Date      Time  Global_active_power  Global_reactive_power  \
# 41    2006-12-16  18:05:00                6.052                  0.192
# 44    2006-12-16  18:08:00                6.308                  0.116
# 17496 2006-12-28  21:00:00                6.376                  0.252
# 17499 2006-12-28  21:03:00                7.906                  0.286
# 17502 2006-12-28  21:06:00                7.184                  0.000
#
#        Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 41      232.93              26.2             0.0            37.0
# 44      232.25              27.0             0.0            36.0
# 17496   235.94              27.4             1.0            53.0
# 17499   235.93              33.6             1.0            73.0
# 17502   235.70              30.4             2.0            73.0
#
#        Sub_metering_3
# 41               17.0
# 44               17.0
# 17496            17.0
# 17499            17.0
# 17502            17.0
# ...

# %% [markdown]
# <h3>NumPy:</h3>

# %%
npdata[:, 1] = np.array([datetime.datetime.strptime(time, '%H:%M:%S').time() for time in npdata[:, 1]])
def select_households_np(nparray):
    
    filtered_np = nparray[(nparray[:, 1]  > datetime.datetime.strptime('18:00:00', '%H:%M:%S').time()) & (nparray[:, 2] > 6.0)]
    final_np = filtered_np[(filtered_np[:, 7] > filtered_np[:, 6]) & (filtered_np[:, 7] > filtered_np[:, 8])]
   
    first_half = final_np[:len(final_np) // 2]
    second_half = final_np[len(final_np) // 2:]
    result_np = np.concatenate([first_half[::3], second_half[::4]])
    
    return result_np

start_time = time.time()
result = select_households_np(npdata)
print(result)
end_time = time.time() - start_time
print(f"Час виконання Pd: {end_time}")
# Out:
# [['2006-12-16 00:00:00' datetime.time(18, 5) 6.052 ... 0.0 37.0 17.0]
#  ['2006-12-16 00:00:00' datetime.time(18, 8) 6.308 ... 0.0 36.0 17.0]
#  ['2006-12-28 00:00:00' datetime.time(20, 58) 6.386 ... 1.0 36.0 17.0]
#  ...
#  ['2010-11-20 00:00:00' datetime.time(18, 39) 6.362 ... 16.0 35.0 16.0]
#  ['2010-11-20 00:00:00' datetime.time(18, 43) 6.324 ... 14.0 35.0 17.0]
#  ['2010-11-20 00:00:00' datetime.time(18, 49) 6.21 ... 21.0 34.0 17.0]]
# Час виконання Pd: 0.1500411033630371

# %% [markdown]
# <h3>Отже, обидва способи працюють досить ефективно, проте DataFrame працює швидше та зручніше. DataFrame має більшу зручність для читання та обробки табличних даних. Проте, якщо дані занадто великі, NumPy array може бути швидшим за рахунок своєї ефективності у використанні пам'яті.</h3>
